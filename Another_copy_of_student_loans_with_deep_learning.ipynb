# %% [markdown]
# <a href="https://colab.research.google.com/github/Pnwankwo2/neural-network-challenge-1/blob/main/Another_copy_of_student_loans_with_deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# Imports
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from pathlib import Path

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student-loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student-loans.csv"
loans_df = pd.read_csv(file_path)

# Review the DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# 2                  0.9970            3.26              0.65
# 3                  0.9980            3.16              0.58
# 4                  0.9978            3.51              0.56
#
#    financial_aid_score  credit_ranking
# 0                  9.4               0
# 1                  9.8               0
# 2                  9.8               0
# 3                  9.8               1
# 4                  9.4               0

# %%
# Review the data types associated with the columns
loans_df.dtypes
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %%
# Check the credit_ranking value counts
loans_df["credit_ranking"].value_counts()
# Out:
# credit_ranking
# 1    855
# 0    744
# Name: count, dtype: int64

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column

y = loans_df["credit_ranking"]
# Display a sample of y
loans_df["credit_ranking"].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# Name: credit_ranking, dtype: int64

# %%
# Define features set X by selecting all columns but credit_ranking
X = loans_df.drop(columns=["credit_ranking"])

# Review the features DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# 2                  0.9970            3.26              0.65
# 3                  0.9980            3.16              0.58
# 4                  0.9978            3.51              0.56
#
#    financial_aid_score  credit_ranking
# 0                  9.4               0
# 1                  9.8               0
# 2                  9.8               0
# 3                  9.8               1
# 4                  9.4               0

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
# Assign the function a random_state equal to 1

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance
standard_scaler = StandardScaler()
standard_scaler.fit(X_train)
X_train = standard_scaler.transform(X_train)
X_test = standard_scaler.transform(X_test)

# Fit the scaler to the features training dataset
standard_scaler.fit(X_train)
standard_scaler.fit(X_test)

# Fit the scaler to the features training dataset
X_train_scaled = standard_scaler.transform(X_train)
X_test_scaled = standard_scaler.transform(X_test)


# Fit the scaler to the features training dataset
X_scaler = standard_scaler.fit(X_train)

# Fit the scaler to the features training dataset
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
# Define the the number of inputs (features) to the model
number_of_features = X_train.shape[1]

# Review the number of features
number_of_features = X_train.shape[1]
print(number_of_features)
# Out:
# 11

# %%
# Define the number of hidden nodes for the first hidden layer


# Define the number of hidden nodes for the second hidden layer


# Define the number of neurons in the output layer

# %%
# Create the Sequential model instance


# Add the first hidden layer


# Add the second hidden layer


# Add the output layer to the model specifying the number of output neurons and activation function

# %%
# Display the Sequential model summary

# %% [markdown]
# ### Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Define the the number of inputs (features) to the model
number_of_features = X_train.shape[1]
number_of_features = X_train.shape[1]

# Review the number of features
print(number_of_features)
# Out:
# 11

# %%
# Fit the model using 50 epochs and the training data
model = Sequential()
model.add(Dense(units=64, activation="relu", input_dim=number_of_features))
model.add(Dense(units=32, activation="relu"))
model.add(Dense(units=1, activation="sigmoid"))
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
model.fit(X_train_scaled, y_train, epochs=50, shuffle=True, verbose=2)
# Out:
# Epoch 1/50
# 40/40 - 1s - 27ms/step - accuracy: 0.6974 - loss: 0.6135
# Epoch 2/50
# 40/40 - 0s - 2ms/step - accuracy: 0.7342 - loss: 0.5394
# Epoch 3/50
# 40/40 - 0s - 2ms/step - accuracy: 0.7498 - loss: 0.5145
# Epoch 4/50
# 40/40 - 0s - 2ms/step - accuracy: 0.7600 - loss: 0.5042
# Epoch 5/50
# 40/40 - 0s - 2ms/step - accuracy: 0.7647 - loss: 0.4954
# Epoch 6/50
# 40/40 - 0s - 3ms/step - accuracy: 0.7631 - loss: 0.4898
# Epoch 7/50
# 40/40 - 0s - 4ms/step - accuracy: 0.7725 - loss: 0.4823
# Epoch 8/50
# 40/40 - 0s - 2ms/step - accuracy: 0.7740 - loss: 0.4752
# Epoch 9/50
# 40/40 - 0s - 4ms/step - accuracy: 0.7725 - loss: 0.4713
# Epoch 10/50
# 40/40 - 0s - 3ms/step - accuracy: 0.7748 - loss: 0.4656
# Epoch 11/50
# 40/40 - 0s - 3ms/step - accuracy: 0.7748 - loss: 0.4614
# Epoch 12/50
# 40/40 - 0s - 3ms/step - accuracy: 0.7811 - loss: 0.4564
# Epoch 13/50
# 40/40 - 0s - 4ms/step - accuracy: 0.7772 - loss: 0.4532
# Epoch 14/50
# 40/40 - 0s - 7ms/step - accuracy: 0.7811 - loss: 0.4505
# Epoch 15/50
# 40/40 - 0s - 3ms/step - accuracy: 0.7803 - loss: 0.4496
# Epoch 16/50
# 40/40 - 0s - 3ms/step - accuracy: 0.7834 - loss: 0.4452
# Epoch 17/50
# 40/40 - 0s - 4ms/step - accuracy: 0.7873 - loss: 0.4396
# Epoch 18/50
# 40/40 - 0s - 3ms/step - accuracy: 0.7881 - loss: 0.4366
# Epoch 19/50
# 40/40 - 0s - 3ms/step - accuracy: 0.7873 - loss: 0.4321
# Epoch 20/50
# 40/40 - 0s - 3ms/step - accuracy: 0.7905 - loss: 0.4287
# Epoch 21/50
# 40/40 - 0s - 3ms/step - accuracy: 0.7920 - loss: 0.4257
# Epoch 22/50
# 40/40 - 0s - 3ms/step - accuracy: 0.7983 - loss: 0.4209
# Epoch 23/50
# 40/40 - 0s - 3ms/step - accuracy: 0.8084 - loss: 0.4168
# Epoch 24/50
# 40/40 - 0s - 3ms/step - accuracy: 0.8022 - loss: 0.4129
# Epoch 25/50
# 40/40 - 0s - 3ms/step - accuracy: 0.7975 - loss: 0.4123
# Epoch 26/50
# 40/40 - 0s - 4ms/step - accuracy: 0.8108 - loss: 0.4056
# Epoch 27/50
# 40/40 - 0s - 6ms/step - accuracy: 0.8084 - loss: 0.4032
# Epoch 28/50
# 40/40 - 0s - 3ms/step - accuracy: 0.8139 - loss: 0.3985
# Epoch 29/50
# 40/40 - 0s - 3ms/step - accuracy: 0.8155 - loss: 0.4006
# Epoch 30/50
# 40/40 - 0s - 2ms/step - accuracy: 0.8163 - loss: 0.3944
# Epoch 31/50
# 40/40 - 0s - 3ms/step - accuracy: 0.8241 - loss: 0.3925
# Epoch 32/50
# 40/40 - 0s - 3ms/step - accuracy: 0.8249 - loss: 0.3875
# Epoch 33/50
# 40/40 - 0s - 4ms/step - accuracy: 0.8264 - loss: 0.3855
# Epoch 34/50
# 40/40 - 0s - 3ms/step - accuracy: 0.8256 - loss: 0.3801
# Epoch 35/50
# 40/40 - 0s - 3ms/step - accuracy: 0.8311 - loss: 0.3754
# Epoch 36/50
# 40/40 - 0s - 3ms/step - accuracy: 0.8350 - loss: 0.3744
# Epoch 37/50
# 40/40 - 0s - 2ms/step - accuracy: 0.8319 - loss: 0.3721
# Epoch 38/50
# 40/40 - 0s - 3ms/step - accuracy: 0.8358 - loss: 0.3673
# Epoch 39/50
# 40/40 - 0s - 2ms/step - accuracy: 0.8421 - loss: 0.3654
# Epoch 40/50
# 40/40 - 0s - 2ms/step - accuracy: 0.8389 - loss: 0.3616
# Epoch 41/50
# 40/40 - 0s - 2ms/step - accuracy: 0.8366 - loss: 0.3590
# Epoch 42/50
# 40/40 - 0s - 4ms/step - accuracy: 0.8428 - loss: 0.3597
# Epoch 43/50
# 40/40 - 0s - 3ms/step - accuracy: 0.8475 - loss: 0.3549
# Epoch 44/50
# 40/40 - 0s - 3ms/step - accuracy: 0.8452 - loss: 0.3538
# Epoch 45/50
# 40/40 - 0s - 3ms/step - accuracy: 0.8522 - loss: 0.3481
# Epoch 46/50
# 40/40 - 0s - 3ms/step - accuracy: 0.8491 - loss: 0.3500
# Epoch 47/50
# 40/40 - 0s - 3ms/step - accuracy: 0.8514 - loss: 0.3452
# Epoch 48/50
# 40/40 - 0s - 3ms/step - accuracy: 0.8530 - loss: 0.3379
# Epoch 49/50
# 40/40 - 0s - 4ms/step - accuracy: 0.8491 - loss: 0.3384
# Epoch 50/50
# 40/40 - 0s - 2ms/step - accuracy: 0.8546 - loss: 0.3343

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data


# Display the model loss and accuracy results

# %% [markdown]
# ### Step 4: Save and export your model to a keras file, and name the file `student_loans.keras`.

# %%
# Set the model's file path


# Export your model to a keras file

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the model's file path
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student_loans.keras"

# Load the model to a new object
model = tf.keras.models.load_model(file_path)



# Load the model to a new object
model = tf.keras.models.load_model(file_path)
# Out:
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# <ipython-input-64-a9f47124fb98> in <cell line: 5>()
#       3
#       4 # Load the model to a new object
# ----> 5 model = tf.keras.models.load_model(file_path)
#       6
#       7
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     177
#     178         # Copy from remote to temporary local directory
# --> 179         file_utils.copy(filepath, local_path)
#     180
#     181         # Switch filepath to local zipfile for loading model
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/file_utils.py in copy(src, dst)
#     476     if is_remote_path(src) or is_remote_path(dst):
#     477         if gfile.available:
# --> 478             return gfile.copy(src, dst, overwrite=True)
#     479         else:
#     480             _raise_if_no_gfile(f"src={src} dst={dst}")
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/lib/io/file_io.py in copy_v2(src, dst, overwrite)
#     579     errors.OpError: If the operation fails.
#     580   """
# --> 581   _pywrap_file_io.CopyFile(
#     582       compat.path_to_bytes(src), compat.path_to_bytes(dst), overwrite)
#     583
#
# UnimplementedError: File system scheme 'https' not implemented (file: 'https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student_loans.keras')

# %% [markdown]
# ### Step 2: Make predictions on the testing data and save the predictions to a DataFrame.

# %%
# Make predictions with the test data


# Display a sample of the predictions
# Out:
# 13/13 - 0s - 126ms/epoch - 10ms/step
# array([[0.63573396],
#        [0.41001907],
#        [0.88199055],
#        [0.61770827],
#        [0.9708398 ]], dtype=float32)

# %%
# Save the predictions to a DataFrame and round the predictions to binary results
# Out:
#      predictions
# 0            1.0
# 1            0.0
# 2            1.0
# 3            1.0
# 4            1.0
# ..           ...
# 395          1.0
# 396          0.0
# 397          1.0
# 398          0.0
# 399          0.0
#
# [400 rows x 1 columns]

# %% [markdown]
# ### Step 4: Display a classification report with the y test data and predictions

# %%
# Print the classification report with the y test data and predictions
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.76      0.73       188
#            1       0.77      0.72      0.74       212
#
#     accuracy                           0.73       400
#    macro avg       0.74      0.74      0.73       400
# weighted avg       0.74      0.73      0.74       400

# %% [markdown]
# ---
# ## Discuss creating a recommendation system for student loans

# %% [markdown]
# Briefly answer the following questions in the space provided:
#
# 1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.
#
# 2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
# 3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.

# %% [markdown]
# **1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.**
#
#
# **2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.**
#
#
# **3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.**
